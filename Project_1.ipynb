# %% [markdown]
# Assignments for Machine learnin on.
# 1. Download the data for CDK2 protein (IC50, Ki, Kd), CHEMBL301
# 2. Open all the separated files with pandas
# 3. Concatenate all the three data files into one.
#
# -> Total molecules
# -> Duplicate entries
# -> Unique entries
# -> Create a mean column for standard value
# Creat a binary and regression dataset

# %%
# Exploratory data analysis of CDK2 protein from CHEMBL database
import pandas as pd
import numpy as np

# %%
import os

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 84A6-AA72
#
#  Directory of C:\Users\nn\Desktop\ureseacher_AIDD
#
# 15/05/2023  11:52    <DIR>          .
# 15/05/2023  11:52    <DIR>          ..
# 15/05/2023  08:10    <DIR>          .ipynb_checkpoints
# 15/05/2023  10:29               786 CDK2_chembl-columns.csv
# 15/05/2023  10:39            15,908 CDK2_duplicates_name.csv
# 15/05/2023  08:58         4,887,614 CDK2_protein.csv
# 15/05/2023  08:58                22 CDK2_protein.zip
# 15/05/2023  09:25               227 data_test_col.csv
# 15/05/2023  05:35           230,210 Installations.zip
# 15/05/2023  06:22    <DIR>          project_1
# 15/05/2023  11:52            60,759 Project_1.ipynb
# 15/05/2023  05:29             1,309 python-commands.py
# 15/05/2023  06:34    <DIR>          shared_data_mldd
#                8 File(s)      5,196,835 bytes
#                5 Dir(s)  35,513,720,832 bytes free

# %%
x = pd.read_csv("CDK2_protein.csv", sep = ";")

# %%
x.tail()
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight
# 8113      CHEMBL1879970           NaN                 NaN            386.49  \
# 8114      CHEMBL5089526           NaN                 NaN            285.77
# 8115      CHEMBL2403108     CERITINIB                 4.0            558.15
# 8116       CHEMBL483847           NaN                 NaN            374.32
# 8117      CHEMBL5083872           NaN                 NaN           1193.38
#
#       #RO5 Violations  AlogP Compound Key
# 8113              0.0   3.30          NaN  \
# 8114              0.0   1.94          NaN
# 8115              2.0   6.36          NaN
# 8116              0.0   3.88          NaN
# 8117              NaN    NaN          NaN
#
#                                                  Smiles Standard Type
# 8113  O=C(O)CCC/C=C\C[C@H]1C(=O)C[C@@H](O)[C@@H]1/C=...      Delta TM  \
# 8114             CCCN1CCO[C@H]2c3cc(O)ccc3OC[C@@H]21.Cl      Delta TM
# ...

# %%
#Check shape
x.shape
# Out:
# (8118, 45)

# %%
#First check all the columns
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
len(x.columns)
# Out:
# 45

# %%
#Save columns into csv by creating Dataframe
columns_name = pd.DataFrame(x.columns, columns=["column_names"])

# %%
columns_name.to_csv("CDK2_chembl-columns.csv", index = None)

# %%
# import pandas as pd

# # List of column names
# column_names_test = ['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase', 'Molecular Weight', '#RO5 Violations',
#                 'AlogP', 'Compound Key', 'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#                 'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment', 'Uo Units']

# # Create an empty DataFrame with the column names
# df_new = pd.DataFrame(columns=column_names_test)

# # Print the DataFrame
# print(df_new)
# df_new.to_csv('data_test_col.csv', index=False)

# %%
columns_name
# Out:
#                   column_names
# 0           Molecule ChEMBL ID
# 1                Molecule Name
# 2           Molecule Max Phase
# 3             Molecular Weight
# 4              #RO5 Violations
# 5                        AlogP
# 6                 Compound Key
# 7                       Smiles
# 8                Standard Type
# 9            Standard Relation
# 10              Standard Value
# 11              Standard Units
# 12               pChEMBL Value
# 13       Data Validity Comment
# 14                     Comment
# 15                    Uo Units
# 16       Ligand Efficiency BEI
# 17        Ligand Efficiency LE
# 18       Ligand Efficiency LLE
# 19       Ligand Efficiency SEI
# 20         Potential Duplicate
# 21             Assay ChEMBL ID
# 22           Assay Description
# 23                  Assay Type
# 24               BAO Format ID
# 25                   BAO Label
# 26              Assay Organism
# 27      Assay Tissue ChEMBL ID
# 28           Assay Tissue Name
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8118 entries, 0 to 8117
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          8118 non-null   object
#  1   Molecule Name               2509 non-null   object
#  2   Molecule Max Phase          819 non-null    float64
#  3   Molecular Weight            8108 non-null   float64
#  4   #RO5 Violations             8089 non-null   float64
#  5   AlogP                       8089 non-null   float64
#  6   Compound Key                7177 non-null   object
#  7   Smiles                      8107 non-null   object
#  8   Standard Type               8118 non-null   object
#  9   Standard Relation           7680 non-null   object
#  10  Standard Value              7792 non-null   float64
#  11  Standard Units              7945 non-null   object
#  12  pChEMBL Value               2599 non-null   float64
# ...

# %%
#Checks for duplicates in particular objects
x.describe(include=["object"])
# Out:
#        Molecule ChEMBL ID Molecule Name Compound Key
# count                8118          2509         7177  \
# unique               5710          1078         3124
# top          CHEMBL428690     ALVOCIDIB            1
# freq                   25            25           81
#
#                                                    Smiles Standard Type
# count                                                8107          8118  \
# unique                                               5701            28
# top     CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc...          IC50
# freq                                                   25          2763
#
#        Standard Relation Standard Units  Data Validity Comment
# count               7680           7945                    108  \
# unique                 4             13                      2
# top                  '='             nM  Outside typical range
# freq                5787           4322                     99
#
# ...

# %%
#To check for duplicate in specific column using value_count
counts=x["Molecule Name"].value_counts().reset_index()

# %%
counts
# Out:
#            Molecule Name  count
# 0              ALVOCIDIB     25
# 1             SELICICLIB     19
# 2             DINACICLIB     15
# 3          STAUROSPORINE     12
# 4             BMS-387032     10
# ...                  ...    ...
# 1073          VOXTALISIB      1
# 1074    ALSTERPAULLONE 2      1
# 1075        LAUROGUADINE      1
# 1076  DESMETHYLALTENUSIN      1
# 1077             IB-MECA      1
#
# [1078 rows x 2 columns]

# %%
counts.head()
# Out:
#    Molecule Name  count
# 0      ALVOCIDIB     25
# 1     SELICICLIB     19
# 2     DINACICLIB     15
# 3  STAUROSPORINE     12
# 4     BMS-387032     10

# %%
counts.to_csv("CDK2_duplicates_name.csv", index = None)

# %%
pd.set_option("display.precision", 4)

# %%
#Normalization
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
#Selecting moe than one coulumn use double square brakcter[[]]
subdata =x[['Molecule ChEMBL ID','Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
       'Standard Units']]

# %%
subdata.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles
# 0       CHEMBL488436    Cc1ncc(-c2ccnc(Nc3ccc(S(C)(=O)=O)cc3)n2)n1C(C)C  \
# 1      CHEMBL4096145  CC1(C)[C@H](Nc2c(C(N)=O)cnn3cc(-c4ccccc4)cc23)...
# 2       CHEMBL296468         CC(C)(C)c1cnc(CSc2cnc(NC(=O)C3CCNCC3)s2)o1
# 3       CHEMBL189963  CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2C...
# 4      CHEMBL3892881  CS(=N)(=O)Cc1cccc(Nc2ncc(F)c(-c3ccc(F)cc3OCc3c...
#
#   Standard Type Standard Relation  Standard Value Standard Units
# 0    Inhibition               NaN             NaN              %
# 1      Activity               '='           100.0              %
# 2            Kd               '='           205.0             nM
# 3          IC50               '='            10.0             nM
# 4          IC50               '='           770.0             nM

# %%
subdata.shape
# Out:
# (8118, 6)

# %%
x["Molecule ChEMBL ID"].value_counts(normalize=True)
# Out:
# Molecule ChEMBL ID
# CHEMBL428690     0.0031
# CHEMBL14762      0.0023
# CHEMBL1234833    0.0022
# CHEMBL319467     0.0021
# CHEMBL2103840    0.0018
#                   ...
# CHEMBL3613691    0.0001
# CHEMBL2347710    0.0001
# CHEMBL14489      0.0001
# CHEMBL3658065    0.0001
# CHEMBL5083872    0.0001
# Name: proportion, Length: 5710, dtype: float64

# %%
subdata.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles
# 0       CHEMBL488436    Cc1ncc(-c2ccnc(Nc3ccc(S(C)(=O)=O)cc3)n2)n1C(C)C  \
# 1      CHEMBL4096145  CC1(C)[C@H](Nc2c(C(N)=O)cnn3cc(-c4ccccc4)cc23)...
# 2       CHEMBL296468         CC(C)(C)c1cnc(CSc2cnc(NC(=O)C3CCNCC3)s2)o1
# 3       CHEMBL189963  CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2C...
# 4      CHEMBL3892881  CS(=N)(=O)Cc1cccc(Nc2ncc(F)c(-c3ccc(F)cc3OCc3c...
#
#   Standard Type Standard Relation  Standard Value Standard Units
# 0    Inhibition               NaN             NaN              %
# 1      Activity               '='           100.0              %
# 2            Kd               '='           205.0             nM
# 3          IC50               '='            10.0             nM
# 4          IC50               '='           770.0             nM

# %%
subdata.shape
# Out:
# (8118, 6)

# %%
subdata["Standard Type"].value_counts()
# Out:
# Standard Type
# IC50                      2763
# Inhibition                2103
# Ki                        1186
# Delta TM                   933
# Kd                         437
# Activity                   304
# Thermal melting change     156
# % Control                  108
# PI                          41
# Cell cycle                  30
# Selectivity                  8
# AC50                         8
# % inhibition                 6
# Ratio IC50                   6
# cKi                          5
# Ratio                        5
# Tm                           4
# Residual_activity            3
# deltaG                       2
# K                            2
# -TdeltaS                     1
# Affinity                     1
# deltaH                       1
# Fold selectivity             1
# pIC50                        1
# Selectivity ratio            1
# Kinact                       1
# Tm shift                     1
# Name: count, dtype: int64

# %%
subdata["Standard Units"].value_counts()
# Out:
# Standard Units
# nM           4322
# %            2460
# C             929
# degrees C     159
# ug.mL-1        52
# uM              9
# kcal/mol        4
# c               4
# °C              2
# 10'3/M/s        1
# 10'6/M/s        1
# µM              1
# /s              1
# Name: count, dtype: int64

# %%
subdata["Standard Units"].str.contains("nM")
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8113    False
# 8114    False
# 8115    False
# 8116    False
# 8117    False
# Name: Standard Units, Length: 8118, dtype: object

# %%
subdata=subdata[subdata["Standard Units"].str.contains("nM", na=False)]

# %%
subdata=subdata.dropna(axis=0)
subdata
# Out:
#       index Molecule ChEMBL ID
# 0      4362       CHEMBL388978  \
# 1       610       CHEMBL476578
# 2      1559       CHEMBL526110
# 3      2731       CHEMBL317703
# 4      2541       CHEMBL321517
# ...     ...                ...
# 4314   2986       CHEMBL456797
# 4315   2391       CHEMBL551612
# 4316   2546       CHEMBL549850
# 4317    367       CHEMBL497454
# 4318   2204       CHEMBL557050
#
#                                                  Smiles Standard Type
# 0     CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50  \
# 1     CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...          IC50
# 2       O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1          IC50
# 3     NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...          IC50
# 4         Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1          IC50
# ...                                                 ...           ...
# 4314  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...          IC50
# ...

# %%
subdata.shape
# Out:
# (4311, 7)

# %%
subdata.head()
# Out:
#    index Molecule ChEMBL ID
# 0   4362       CHEMBL388978  \
# 1    610       CHEMBL476578
# 2   1559       CHEMBL526110
# 3   2731       CHEMBL317703
# 4   2541       CHEMBL321517
#
#                                               Smiles Standard Type
# 0  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50  \
# 1  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...          IC50
# 2    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1          IC50
# 3  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...          IC50
# 4      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1          IC50
#
#   Standard Relation  Standard Value Standard Units
# 0               '='            0.10             nM
# 1               '>'            0.30             nM
# 2               '='            0.30             nM
# 3               '='            0.33             nM
# 4               '='            0.34             nM

# %%
subdata.tail()
# Out:
#       index Molecule ChEMBL ID
# 4314   2986       CHEMBL456797  \
# 4315   2391       CHEMBL551612
# 4316   2546       CHEMBL549850
# 4317    367       CHEMBL497454
# 4318   2204       CHEMBL557050
#
#                                                  Smiles Standard Type
# 4314  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...          IC50  \
# 4315         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12          IC50
# 4316                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21          IC50
# 4317       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1          IC50
# 4318                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21          IC50
#
#      Standard Relation  Standard Value Standard Units
# 4314               '='       1109000.0             nM
# 4315               '='       1160000.0             nM
# 4316               '='       1210000.0             nM
# 4317               '='       1216000.0             nM
# 4318               '='       1230000.0             nM

# %%
#Sort data
subdata=subdata.sort_values("Standard Value", ascending=True).reset_index(drop=True)

# %%
subdata
# Out:
#       index Molecule ChEMBL ID
# 0      4362       CHEMBL388978  \
# 1       610       CHEMBL476578
# 2      1559       CHEMBL526110
# 3      2731       CHEMBL317703
# 4      2541       CHEMBL321517
# ...     ...                ...
# 4306   2986       CHEMBL456797
# 4307   2391       CHEMBL551612
# 4308   2546       CHEMBL549850
# 4309    367       CHEMBL497454
# 4310   2204       CHEMBL557050
#
#                                                  Smiles Standard Type
# 0     CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50  \
# 1     CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...          IC50
# 2       O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1          IC50
# 3     NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...          IC50
# 4         Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1          IC50
# ...                                                 ...           ...
# 4306  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...          IC50
# ...

# %%
subdata["Standard Type"].value_counts()
# Out:
# Standard Type
# IC50          2665
# Ki            1183
# Kd             420
# Cell cycle      30
# AC50             8
# cKi              5
# Name: count, dtype: int64

# %%
IC50 = subdata[subdata["Standard Type"].str.contains("IC50")]

# %%
IC50
# Out:
#       index Molecule ChEMBL ID
# 0      4362       CHEMBL388978  \
# 1       610       CHEMBL476578
# 2      1559       CHEMBL526110
# 3      2731       CHEMBL317703
# 4      2541       CHEMBL321517
# ...     ...                ...
# 4306   2986       CHEMBL456797
# 4307   2391       CHEMBL551612
# 4308   2546       CHEMBL549850
# 4309    367       CHEMBL497454
# 4310   2204       CHEMBL557050
#
#                                                  Smiles Standard Type
# 0     CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50  \
# 1     CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...          IC50
# 2       O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1          IC50
# 3     NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...          IC50
# 4         Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1          IC50
# ...                                                 ...           ...
# 4306  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...          IC50
# ...

# %%
newdata = subdata[["Molecule ChEMBL ID","Standard Value"]]

# %%
newdata["Standard Value"].max()
# Out:
# 1230000.0

# %%
# You can use the standard value for Binary classification e.g the lower the standard value = active, while higher = inactive.
# Value <= 10000 nM as "Active/Positive/1"
# Value >= 20000 nM as "Inactive/Negative/2"

# %%
newdata["Molecule ChEMBL ID"].value_counts()
# Out:
# Molecule ChEMBL ID
# CHEMBL428690     24
# CHEMBL14762      15
# CHEMBL2103840    12
# CHEMBL129396     10
# CHEMBL319467     10
#                  ..
# CHEMBL520353      1
# CHEMBL127907      1
# CHEMBL122264      1
# CHEMBL116070      1
# CHEMBL557050      1
# Name: count, Length: 3550, dtype: int64

# %%
newdata[newdata["Molecule ChEMBL ID"].str.contains("CHEMBL428690")]
# Out:
#      Molecule ChEMBL ID  Standard Value
# 16         CHEMBL428690             1.0
# 37         CHEMBL428690             1.0
# 68         CHEMBL428690             2.0
# 359        CHEMBL428690             9.0
# 448        CHEMBL428690            12.0
# 513        CHEMBL428690            16.0
# 601        CHEMBL428690            23.0
# 624        CHEMBL428690            25.0
# 738        CHEMBL428690            40.0
# 740        CHEMBL428690            40.0
# 874        CHEMBL428690            60.0
# 888        CHEMBL428690            61.0
# 936        CHEMBL428690            70.0
# 1217       CHEMBL428690           170.0
# 1220       CHEMBL428690           170.0
# 1223       CHEMBL428690           170.0
# 1225       CHEMBL428690           170.0
# 1227       CHEMBL428690           170.0
# 1249       CHEMBL428690           190.0
# 1271       CHEMBL428690           200.0
# 1511       CHEMBL428690           400.0
# 1627       CHEMBL428690           550.0
# ...

# %%
#Select the active ones based nM value
newdata.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Standard Value'], dtype='object')

# %%
newdata["new_value"] = newdata[['Molecule ChEMBL ID', 'Standard Value']].groupby(["Molecule ChEMBL ID"])['Standard Value'].transform("mean")
# Out:
# C:\Users\nn\AppData\Local\Temp\ipykernel_16928\3311567739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdata["new_value"] = newdata[['Molecule ChEMBL ID', 'Standard Value']].groupby(["Molecule ChEMBL ID"])['Standard Value'].transform("mean")

# %%
newdata.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value
# 0       CHEMBL388978            0.10      3.795
# 1       CHEMBL476578            0.30      0.300
# 2       CHEMBL526110            0.30      0.300
# 3       CHEMBL317703            0.33      0.330
# 4       CHEMBL321517            0.34      0.340

# %%
newdata[newdata["Molecule ChEMBL ID"].str.contains("CHEMBL428690")]
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value
# 16         CHEMBL428690             1.0    184.875
# 37         CHEMBL428690             1.0    184.875
# 68         CHEMBL428690             2.0    184.875
# 359        CHEMBL428690             9.0    184.875
# 448        CHEMBL428690            12.0    184.875
# 513        CHEMBL428690            16.0    184.875
# 601        CHEMBL428690            23.0    184.875
# 624        CHEMBL428690            25.0    184.875
# 738        CHEMBL428690            40.0    184.875
# 740        CHEMBL428690            40.0    184.875
# 874        CHEMBL428690            60.0    184.875
# 888        CHEMBL428690            61.0    184.875
# 936        CHEMBL428690            70.0    184.875
# 1217       CHEMBL428690           170.0    184.875
# 1220       CHEMBL428690           170.0    184.875
# 1223       CHEMBL428690           170.0    184.875
# 1225       CHEMBL428690           170.0    184.875
# ...

# %%
CHEMBL428690 = newdata[newdata["Molecule ChEMBL ID"].str.contains("CHEMBL428690")]
CHEMBL428690["Standard Value"].mean()
# Out:
# 184.875

# %%
newdata.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value
# 0       CHEMBL388978            0.10      3.795
# 1       CHEMBL476578            0.30      0.300
# 2       CHEMBL526110            0.30      0.300
# 3       CHEMBL317703            0.33      0.330
# 4       CHEMBL321517            0.34      0.340

# %%
#Now sort the values
newdata = newdata.sort_values("new_value", ascending=False)
newdata
# Out:
#      Molecule ChEMBL ID  Standard Value   new_value
# 4310       CHEMBL557050      1.2300e+06  1.2300e+06
# 4309       CHEMBL497454      1.2160e+06  1.2160e+06
# 4308       CHEMBL549850      1.2100e+06  1.2100e+06
# 4307       CHEMBL551612      1.1600e+06  1.1600e+06
# 4306       CHEMBL456797      1.1090e+06  1.1090e+06
# ...                 ...             ...         ...
# 6          CHEMBL476577      5.0000e-01  5.0000e-01
# 4          CHEMBL321517      3.4000e-01  3.4000e-01
# 3          CHEMBL317703      3.3000e-01  3.3000e-01
# 1          CHEMBL476578      3.0000e-01  3.0000e-01
# 2          CHEMBL526110      3.0000e-01  3.0000e-01
#
# [4311 rows x 3 columns]

# %%
newdata["Molecule ChEMBL ID"].value_counts()
# Out:
# Molecule ChEMBL ID
# CHEMBL428690     24
# CHEMBL14762      15
# CHEMBL2103840    12
# CHEMBL125401     10
# CHEMBL129396     10
#                  ..
# CHEMBL1979855     1
# CHEMBL1242373     1
# CHEMBL1975900     1
# CHEMBL1988594     1
# CHEMBL526110      1
# Name: count, Length: 3550, dtype: int64

# %%
newdata
# Out:
#      Molecule ChEMBL ID  Standard Value   new_value
# 4310       CHEMBL557050      1.2300e+06  1.2300e+06
# 4309       CHEMBL497454      1.2160e+06  1.2160e+06
# 4308       CHEMBL549850      1.2100e+06  1.2100e+06
# 4307       CHEMBL551612      1.1600e+06  1.1600e+06
# 4306       CHEMBL456797      1.1090e+06  1.1090e+06
# ...                 ...             ...         ...
# 6          CHEMBL476577      5.0000e-01  5.0000e-01
# 4          CHEMBL321517      3.4000e-01  3.4000e-01
# 3          CHEMBL317703      3.3000e-01  3.3000e-01
# 1          CHEMBL476578      3.0000e-01  3.0000e-01
# 2          CHEMBL526110      3.0000e-01  3.0000e-01
#
# [4311 rows x 3 columns]

# %%
#Drop the duplicates but keep the first, i.e the highest number
newdata= newdata.drop_duplicates("Molecule ChEMBL ID", keep="first")
newdata
# Out:
#      Molecule ChEMBL ID  Standard Value   new_value
# 4310       CHEMBL557050      1.2300e+06  1.2300e+06
# 4309       CHEMBL497454      1.2160e+06  1.2160e+06
# 4308       CHEMBL549850      1.2100e+06  1.2100e+06
# 4307       CHEMBL551612      1.1600e+06  1.1600e+06
# 4306       CHEMBL456797      1.1090e+06  1.1090e+06
# ...                 ...             ...         ...
# 6          CHEMBL476577      5.0000e-01  5.0000e-01
# 4          CHEMBL321517      3.4000e-01  3.4000e-01
# 3          CHEMBL317703      3.3000e-01  3.3000e-01
# 1          CHEMBL476578      3.0000e-01  3.0000e-01
# 2          CHEMBL526110      3.0000e-01  3.0000e-01
#
# [3550 rows x 3 columns]

# %%
#Now no more duplicates
newdata["Molecule ChEMBL ID"].value_counts()
# Out:
# Molecule ChEMBL ID
# CHEMBL557050     1
# CHEMBL189352     1
# CHEMBL1957231    1
# CHEMBL1998826    1
# CHEMBL1957092    1
#                 ..
# CHEMBL220057     1
# CHEMBL1986328    1
# CHEMBL1980142    1
# CHEMBL183844     1
# CHEMBL526110     1
# Name: count, Length: 3550, dtype: int64

# %%
# You can use the standard value for Binary classification e.g the lower the standard value = active, while higher = inactive.
# Value <= 10000 nM as "Active/Positive/1"
# Value >= 20000 nM as "Inactive/Negative/2"

# %%
newdata.head()
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value
# 4310       CHEMBL557050       1230000.0  1230000.0
# 4309       CHEMBL497454       1216000.0  1216000.0
# 4308       CHEMBL549850       1210000.0  1210000.0
# 4307       CHEMBL551612       1160000.0  1160000.0
# 4306       CHEMBL456797       1109000.0  1109000.0

# %%
active = newdata.loc[newdata['new_value'] <= 10000]
active
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value
# 3319      CHEMBL2023197        10000.00   10000.00
# 3151       CHEMBL261849        10000.00   10000.00
# 3176      CHEMBL3589674        10000.00   10000.00
# 3150       CHEMBL474600        10000.00   10000.00
# 3314      CHEMBL3903725        10000.00   10000.00
# ...                 ...             ...        ...
# 6          CHEMBL476577            0.50       0.50
# 4          CHEMBL321517            0.34       0.34
# 3          CHEMBL317703            0.33       0.33
# 1          CHEMBL476578            0.30       0.30
# 2          CHEMBL526110            0.30       0.30
#
# [2644 rows x 3 columns]

# %%
active=active.sort_values("new_value", ascending=True).reset_index(drop=True)

# %%
active
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value
# 0          CHEMBL526110            0.30       0.30
# 1          CHEMBL476578            0.30       0.30
# 2          CHEMBL317703            0.33       0.33
# 3          CHEMBL321517            0.34       0.34
# 4          CHEMBL476577            0.50       0.50
# ...                 ...             ...        ...
# 2639       CHEMBL474433        10000.00   10000.00
# 2640      CHEMBL1088633        10000.00   10000.00
# 2641      CHEMBL3589656        10000.00   10000.00
# 2642       CHEMBL323417        10000.00   10000.00
# 2643      CHEMBL2023197        10000.00   10000.00
#
# [2644 rows x 3 columns]

# %%
#For the inactive molecule
inactive = newdata.loc[newdata['new_value'] >= 10000]
inactive=inactive.sort_values("new_value", ascending=True).reset_index(drop=True)
inactive
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value
# 0         CHEMBL3589664         10000.0    10000.0
# 1         CHEMBL3589671         10000.0    10000.0
# 2         CHEMBL2204532         10000.0    10000.0
# 3         CHEMBL1241674         10000.0    10000.0
# 4         CHEMBL1614712         10000.0    10000.0
# ...                 ...             ...        ...
# 1063       CHEMBL456797       1109000.0  1109000.0
# 1064       CHEMBL551612       1160000.0  1160000.0
# 1065       CHEMBL549850       1210000.0  1210000.0
# 1066       CHEMBL497454       1216000.0  1216000.0
# 1067       CHEMBL557050       1230000.0  1230000.0
#
# [1068 rows x 3 columns]

# %%
active.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value
# 0       CHEMBL526110            0.30       0.30
# 1       CHEMBL476578            0.30       0.30
# 2       CHEMBL317703            0.33       0.33
# 3       CHEMBL321517            0.34       0.34
# 4       CHEMBL476577            0.50       0.50

# %%
active["label"] = 1
active.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value  label
# 0       CHEMBL526110            0.30       0.30      1
# 1       CHEMBL476578            0.30       0.30      1
# 2       CHEMBL317703            0.33       0.33      1
# 3       CHEMBL321517            0.34       0.34      1
# 4       CHEMBL476577            0.50       0.50      1

# %%
inactive["label"] = 0
inactive.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value  label
# 0      CHEMBL3589664         10000.0    10000.0      0
# 1      CHEMBL3589671         10000.0    10000.0      0
# 2      CHEMBL2204532         10000.0    10000.0      0
# 3      CHEMBL1241674         10000.0    10000.0      0
# 4      CHEMBL1614712         10000.0    10000.0      0

# %%
#Combine the active and inactive
combined = pd.concat([active, inactive], axis=0)
combined
# Out:
#      Molecule ChEMBL ID  Standard Value   new_value  label
# 0          CHEMBL526110      3.0000e-01  3.0000e-01      1
# 1          CHEMBL476578      3.0000e-01  3.0000e-01      1
# 2          CHEMBL317703      3.3000e-01  3.3000e-01      1
# 3          CHEMBL321517      3.4000e-01  3.4000e-01      1
# 4          CHEMBL476577      5.0000e-01  5.0000e-01      1
# ...                 ...             ...         ...    ...
# 1063       CHEMBL456797      1.1090e+06  1.1090e+06      0
# 1064       CHEMBL551612      1.1600e+06  1.1600e+06      0
# 1065       CHEMBL549850      1.2100e+06  1.2100e+06      0
# 1066       CHEMBL497454      1.2160e+06  1.2160e+06      0
# 1067       CHEMBL557050      1.2300e+06  1.2300e+06      0
#
# [3712 rows x 4 columns]

# %%
combined.shape
# Out:
# (3712, 4)

# %%
combined.tail()
# Out:
#      Molecule ChEMBL ID  Standard Value  new_value  label
# 1063       CHEMBL456797       1109000.0  1109000.0      0
# 1064       CHEMBL551612       1160000.0  1160000.0      0
# 1065       CHEMBL549850       1210000.0  1210000.0      0
# 1066       CHEMBL497454       1216000.0  1216000.0      0
# 1067       CHEMBL557050       1230000.0  1230000.0      0

# %%
labelled = combined[["Molecule ChEMBL ID", "label"]]

# %%
combined
# Out:
#      Molecule ChEMBL ID  Standard Value   new_value  label
# 0          CHEMBL526110      3.0000e-01  3.0000e-01      1
# 1          CHEMBL476578      3.0000e-01  3.0000e-01      1
# 2          CHEMBL317703      3.3000e-01  3.3000e-01      1
# 3          CHEMBL321517      3.4000e-01  3.4000e-01      1
# 4          CHEMBL476577      5.0000e-01  5.0000e-01      1
# ...                 ...             ...         ...    ...
# 1063       CHEMBL456797      1.1090e+06  1.1090e+06      0
# 1064       CHEMBL551612      1.1600e+06  1.1600e+06      0
# 1065       CHEMBL549850      1.2100e+06  1.2100e+06      0
# 1066       CHEMBL497454      1.2160e+06  1.2160e+06      0
# 1067       CHEMBL557050      1.2300e+06  1.2300e+06      0
#
# [3712 rows x 4 columns]

# %%
#Find two common columns
common = pd.merge(combined, subdata, on="Molecule ChEMBL ID")

# %%
common
# Out:
#      Molecule ChEMBL ID  Standard Value_x   new_value  label  index
# 0          CHEMBL526110        3.0000e-01  3.0000e-01      1   1559  \
# 1          CHEMBL476578        3.0000e-01  3.0000e-01      1    610
# 2          CHEMBL317703        3.3000e-01  3.3000e-01      1   2731
# 3          CHEMBL321517        3.4000e-01  3.4000e-01      1   2541
# 4          CHEMBL476577        5.0000e-01  5.0000e-01      1     84
# ...                 ...               ...         ...    ...    ...
# 4470       CHEMBL456797        1.1090e+06  1.1090e+06      0   2986
# 4471       CHEMBL551612        1.1600e+06  1.1600e+06      0   2391
# 4472       CHEMBL549850        1.2100e+06  1.2100e+06      0   2546
# 4473       CHEMBL497454        1.2160e+06  1.2160e+06      0    367
# 4474       CHEMBL557050        1.2300e+06  1.2300e+06      0   2204
#
#                                                  Smiles Standard Type
# 0       O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1          IC50  \
# ...

# %%
common=common[["Molecule ChEMBL ID","Smiles", "label"]]

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
common=common.drop_duplicates("Molecule ChEMBL ID", keep="first")

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
common.shape
# Out:
# (3550, 3)

# %%
combined.shape
# Out:
# (3712, 4)

# %%
common1 = pd.merge(combined, x,how="outer", on=["Molecule ChEMBL ID"], indicator = True)

# %%
common1
# Out:
#      Molecule ChEMBL ID  Standard Value_x  new_value  label Molecule Name
# 0          CHEMBL526110              0.30       0.30    1.0           NaN  \
# 1          CHEMBL476578              0.30       0.30    1.0           NaN
# 2          CHEMBL317703              0.33       0.33    1.0           NaN
# 3          CHEMBL321517              0.34       0.34    1.0           NaN
# 4          CHEMBL476577              0.50       0.50    1.0           NaN
# ...                 ...               ...        ...    ...           ...
# 8307      CHEMBL5081896               NaN        NaN    NaN           NaN
# 8308       CHEMBL119709               NaN        NaN    NaN       IB-MECA
# 8309      CHEMBL1879970               NaN        NaN    NaN           NaN
# 8310      CHEMBL5089526               NaN        NaN    NaN           NaN
# 8311      CHEMBL5083872               NaN        NaN    NaN           NaN
#
#       Molecule Max Phase  Molecular Weight  #RO5 Violations  AlogP
# ...

# %%
common1["_merge"].value_counts()
# Out:
# _merge
# both          5050
# right_only    3262
# left_only        0
# Name: count, dtype: int64

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
common["Smiles"].value_counts()
# Out:
# Smiles
# O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1                          1
# Cn1nc(C(F)(F)F)c2c(=O)c3cc(Cl)ccc3n(O)c21                                1
# Cc1cccc(NC(=O)Nc2ccc(-c3csc4c(C#CC(C)(C)N)cnc(N)c34)cc2)c1               1
# NC(=O)C1CCCN(C(=O)c2cc(-c3ccc4[nH]ncc4c3)on2)C1                          1
# O=C(Cc1ccccc1)Nc1cccc(-c2nc3sccn3c2-c2ccnc(Nc3cccc(N4CCCC4=O)c3)n2)c1    1
#                                                                         ..
# COC(C(=O)N1Cc2[nH]nc(NC(=O)c3ccc(N4CCN(C)CC4)cc3)c2C1)c1ccccc1           1
# COc1ccc(-c2ocnc2C(=O)NCc2ccnnc2)cc1Cl                                    1
# Nc1n[nH]c2ccc(-c3cn(Cc4ccccc4)nn3)cc12                                   1
# NC(=O)c1ccc(Nc2ncnc3[nH]cc(-c4ccccc4)c23)cc1                             1
# c1ccc2c(c1)CCN2CCN1CCc2ccccc21                                           1
# Name: count, Length: 3550, dtype: int64

# %%
common.to_csv("CDK2_labelled_data.csv", index=None)

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
common["newid"] = common["Molecule ChEMBL ID"].astype(str)+"_"+common["label"].astype(str)
# Out:
# C:\Users\nn\AppData\Local\Temp\ipykernel_16928\1132494280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common["newid"] = common["Molecule ChEMBL ID"].astype(str)+"_"+common["label"].astype(str)

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label           newid
# 0         1  CHEMBL526110_1
# ...

# %%
common[["Smiles","label"]].to_csv("CDK2_labelled.smi", index = None, header=False, sep="\t")

# %%
x.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight
# 0       CHEMBL488436      AZD-5438                 1.0            371.47  \
# 1      CHEMBL4096145           NaN                 NaN            377.49
# 2       CHEMBL296468    BMS-387032                 1.0            380.54
# 3       CHEMBL189963   PALBOCICLIB                 4.0            447.54
# 4      CHEMBL3892881           NaN                 NaN            498.53
#
#    #RO5 Violations  AlogP Compound Key
# 0              0.0   3.38      AZD5438  \
# 1              0.0   3.42            2
# 2              0.0   3.66   BMS-387032
# 3              0.0   2.97  Palbociclib
# 4              1.0   6.06   BDBM180850
#
#                                               Smiles Standard Type
# 0    Cc1ncc(-c2ccnc(Nc3ccc(S(C)(=O)=O)cc3)n2)n1C(C)C    Inhibition  \
# 1  CC1(C)[C@H](Nc2c(C(N)=O)cnn3cc(-c4ccccc4)cc23)...      Activity
# 2         CC(C)(C)c1cnc(CSc2cnc(NC(=O)C3CCNCC3)s2)o1            Kd
# ...

# %%
#Checking for missing values in x
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
#Checking for missing specific values in x
x["Standard Value"].isnull().values.any()
# Out:
# True

# %%
x["Standard Value"].isnull().sum()
# Out:
# 326

# %%
x.isnull().sum()
# Out:
# Molecule ChEMBL ID               0
# Molecule Name                 5609
# Molecule Max Phase            7299
# Molecular Weight                10
# #RO5 Violations                 29
# AlogP                           29
# Compound Key                   941
# Smiles                          11
# Standard Type                    0
# Standard Relation              438
# Standard Value                 326
# Standard Units                 173
# pChEMBL Value                 5519
# Data Validity Comment         8010
# Comment                       5170
# Uo Units                      1116
# Ligand Efficiency BEI         5946
# Ligand Efficiency LE          5950
# Ligand Efficiency LLE         5950
# Ligand Efficiency SEI         5950
# Potential Duplicate              0
# Assay ChEMBL ID                  0
# Assay Description                0
# Assay Type                       0
# BAO Format ID                    0
# BAO Label                        0
# Assay Organism                5487
# ...

# %%
x["pChEMBL Value"].dropna(axis=0)
# Out:
# 2       6.69
# 3       8.00
# 4       6.11
# 5       6.89
# 6       6.64
#         ...
# 7934    5.51
# 7937    6.97
# 7938    6.24
# 7955    6.08
# 8000    5.37
# Name: pChEMBL Value, Length: 2599, dtype: float64

# %%
x.replace

# %%
common
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0          CHEMBL526110    O=[N+]([O-])c1cccc(Nc2nccc(-c3cnn4ncccc34)n2)c1  \
# 1          CHEMBL476578  CC(=O)N[C@@H]1CCN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4...
# 2          CHEMBL317703  NS(=O)(=O)c1ccc(Nc2cc(-c3ccc([N+](=O)[O-])cc3)...
# 3          CHEMBL321517      Nc1ccc(-c2cc(Nc3ccc(S(N)(=O)=O)cc3)[nH]n2)cc1
# 4          CHEMBL476577  CC(=O)NC1CN(c2ccc(Nc3ncc(F)c(-c4cnc(C)n4C(C)C)...
# ...                 ...                                                ...
# 4470       CHEMBL456797  COc1ccccc1-c1cccc(C(=O)N2CCc3c([nH]c4ccccc34)C...
# 4471       CHEMBL551612         O=C(C(=O)N1CCc2ccccc21)c1c[nH]c2ccc(F)cc12
# 4472       CHEMBL549850                 c1ccc2c(c1)ccn2CCCCCCn1ccc2ccccc21
# 4473       CHEMBL497454       O=C(NCCc1c[nH]c2ccccc12)c1ccccc1-c1ccc(F)cc1
# 4474       CHEMBL557050                     c1ccc2c(c1)CCN2CCN1CCc2ccccc21
#
#       label           newid
# 0         1  CHEMBL526110_1
# ...

# %%
# !pip install seaborn
# Out:
# ...
#                                               0.0/293.3 kB ? eta -:--:--
#      -                                        10.2/293.3 kB ? eta -:--:--
#      -                                        10.2/293.3 kB ? eta -:--:--
#      -------                               61.4/293.3 kB 544.7 kB/s eta 0:00:01
#      -----------------------------------    276.5/293.3 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels = common["label"].value_counts().reset_index()

# %%
labels
# Out:
#    label  count
# 0      1   2644
# 1      0    906

# %%
sns.countplot(x="index", hue="label", data=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 sns.countplot(x="index", hue="label", data=labels)
#
# File ~\miniconda3\envs\project\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="index", hue="label", data=labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[222], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.countplot(x="index", hue="label", data=labels)
#       5 plt.show()
#
# File ~\miniconda3\envs\project\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
labels.columns
# Out:
# Index(['label', 'count'], dtype='object')

# %%
active.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  new_value  label
# 0       CHEMBL526110            0.30       0.30      1
# 1       CHEMBL476578            0.30       0.30      1
# 2       CHEMBL317703            0.33       0.33      1
# 3       CHEMBL321517            0.34       0.34      1
# 4       CHEMBL476577            0.50       0.50      1

# %%
active["new_value"].hist(bins=30, grid=False)
plt.xlabel("Value")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
inactive["new_value"].hist(bins=30, grid=False)
plt.xlabel("Value")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
x["Molecule ChEMBL ID"].value_counts()
# Out:
# Molecule ChEMBL ID
# CHEMBL428690     25
# CHEMBL14762      19
# CHEMBL1234833    18
# CHEMBL319467     17
# CHEMBL2103840    15
#                  ..
# CHEMBL3613691     1
# CHEMBL2347710     1
# CHEMBL14489       1
# CHEMBL3658065     1
# CHEMBL5083872     1
# Name: count, Length: 5710, dtype: int64

# %%
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
frequent_binders=x.groupby("Molecule ChEMBL ID").filter(lambda x: len(x)>15)

# %%
frequent_binders["Molecule ChEMBL ID"].value_counts()
# Out:
# Molecule ChEMBL ID
# CHEMBL428690     25
# CHEMBL14762      19
# CHEMBL1234833    18
# CHEMBL319467     17
# Name: count, dtype: int64

# %%
frequent_binders
# Out:
#      Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight
# 252         CHEMBL14762     SELICICLIB                 2.0            354.46  \
# 264        CHEMBL319467            NaN                 NaN            402.48
# 296        CHEMBL388978  STAUROSPORINE                 NaN            466.54
# 306         CHEMBL14762     SELICICLIB                 2.0            354.46
# 314        CHEMBL428690      ALVOCIDIB                 3.0            401.85
# ...                 ...            ...                 ...               ...
# 7441       CHEMBL428690      ALVOCIDIB                 3.0            401.85
# 7458       CHEMBL319467            NaN                 NaN            402.48
# 7667        CHEMBL14762     SELICICLIB                 2.0            354.46
# 7692       CHEMBL319467            NaN                 NaN            402.48
# 7766       CHEMBL388978  STAUROSPORINE                 NaN            466.54
#
# ...

# %%
x
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight
# 0          CHEMBL488436      AZD-5438                 1.0            371.47  \
# 1         CHEMBL4096145           NaN                 NaN            377.49
# 2          CHEMBL296468    BMS-387032                 1.0            380.54
# 3          CHEMBL189963   PALBOCICLIB                 4.0            447.54
# 4         CHEMBL3892881           NaN                 NaN            498.53
# ...                 ...           ...                 ...               ...
# 8113      CHEMBL1879970           NaN                 NaN            386.49
# 8114      CHEMBL5089526           NaN                 NaN            285.77
# 8115      CHEMBL2403108     CERITINIB                 4.0            558.15
# 8116       CHEMBL483847           NaN                 NaN            374.32
# 8117      CHEMBL5083872           NaN                 NaN           1193.38
#
#       #RO5 Violations  AlogP Compound Key
# ...

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[251], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 c= str(x).corr()
#
# AttributeError: 'str' object has no attribute 'corr'

# %%
sns.heatmap
